# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler, MinMaxScaler, LabelEncoder

# %%
df = pd.read_csv('adult_with_headers .csv')

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.head()
# Out:
#    age          workclass  fnlwgt   education  education_num  \
# 0   39          State-gov   77516   Bachelors             13
# 1   50   Self-emp-not-inc   83311   Bachelors             13
# 2   38            Private  215646     HS-grad              9
# 3   53            Private  234721        11th              7
# 4   28            Private  338409   Bachelors             13
#
#         marital_status          occupation    relationship    race      sex  \
# 0        Never-married        Adm-clerical   Not-in-family   White     Male
# 1   Married-civ-spouse     Exec-managerial         Husband   White     Male
# 2             Divorced   Handlers-cleaners   Not-in-family   White     Male
# 3   Married-civ-spouse   Handlers-cleaners         Husband   Black     Male
# 4   Married-civ-spouse      Prof-specialty            Wife   Black   Female
#
#    capital_gain  capital_loss  hours_per_week  native_country  income
# 0          2174             0              40   United-States   <=50K
# 1             0             0              13   United-States   <=50K
# 2             0             0              40   United-States   <=50K
# 3             0             0              40   United-States   <=50K
# 4             0             0              40            Cuba   <=50K

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       32561 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education_num   32561 non-null  int64
#  5   marital_status  32561 non-null  object
#  6   occupation      32561 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital_gain    32561 non-null  int64
#  11  capital_loss    32561 non-null  int64
#  12  hours_per_week  32561 non-null  int64
#  13  native_country  32561 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
df.isnull().sum()
# Out:
# age               0
# workclass         0
# fnlwgt            0
# education         0
# education_num     0
# marital_status    0
# occupation        0
# relationship      0
# race              0
# sex               0
# capital_gain      0
# capital_loss      0
# hours_per_week    0
# native_country    0
# income            0
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(24)

# %%
df.drop_duplicates(inplace=True,ignore_index=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# Identify categorical and numerical columns
num_cols = df.select_dtypes(include=['int64', 'float64']).columns.tolist()
cat_cols = df.select_dtypes(include=['object']).columns.tolist()

# %%
num_cols
# Out:
# ['age',
#  'fnlwgt',
#  'education_num',
#  'capital_gain',
#  'capital_loss',
#  'hours_per_week']

# %%
cat_cols
# Out:
# ['workclass',
#  'education',
#  'marital_status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'native_country',
#  'income']

# %%
# 3️ Scaling
scaler_standard = StandardScaler()
scaler_minmax = MinMaxScaler()

# %%
scaled_standard = pd.DataFrame(scaler_standard.fit_transform(df[num_cols]), columns=[num_cols])
scaled_minmax = pd.DataFrame(scaler_minmax.fit_transform(df[num_cols]), columns=[f"{c}_minmax" for c in num_cols])

# %%
scaled_standard
# Out:
#             age    fnlwgt education_num capital_gain capital_loss  \
# 0      0.030390 -1.063569      1.134777     0.148292    -0.216743
# 1      0.836973 -1.008668      1.134777    -0.145975    -0.216743
# 2     -0.042936  0.245040     -0.420679    -0.145975    -0.216743
# 3      1.056950  0.425752     -1.198407    -0.145975    -0.216743
# 4     -0.776193  1.408066      1.134777    -0.145975    -0.216743
# ...         ...       ...           ...          ...          ...
# 32532 -0.849519  0.639678      0.745913    -0.145975    -0.216743
# 32533  0.103716 -0.335436     -0.420679    -0.145975    -0.216743
# 32534  1.423579 -0.358779     -0.420679    -0.145975    -0.216743
# 32535 -1.216148  0.110930     -0.420679    -0.145975    -0.216743
# 32536  0.983625  0.929812     -0.420679     1.887635    -0.216743
#
#       hours_per_week
# 0          -0.035664
# 1          -2.222483
# 2          -0.035664
# 3          -0.035664
# 4          -0.035664
# ...              ...
# 32532      -0.197650
# 32533      -0.035664
# 32534      -0.035664
# 32535      -1.655530
# 32536      -0.035664
#
# [32537 rows x 6 columns]

# %%
scaled_minmax
# Out:
#        age_minmax  fnlwgt_minmax  education_num_minmax  capital_gain_minmax  \
# 0        0.301370       0.044302              0.800000             0.021740
# 1        0.452055       0.048238              0.800000             0.000000
# 2        0.287671       0.138113              0.533333             0.000000
# 3        0.493151       0.151068              0.400000             0.000000
# 4        0.150685       0.221488              0.800000             0.000000
# ...           ...            ...                   ...                  ...
# 32532    0.136986       0.166404              0.733333             0.000000
# 32533    0.315068       0.096500              0.533333             0.000000
# 32534    0.561644       0.094827              0.533333             0.000000
# 32535    0.068493       0.128499              0.533333             0.000000
# 32536    0.479452       0.187203              0.533333             0.150242
#
#        capital_loss_minmax  hours_per_week_minmax
# 0                      0.0               0.397959
# 1                      0.0               0.122449
# 2                      0.0               0.397959
# 3                      0.0               0.397959
# 4                      0.0               0.397959
# ...                    ...                    ...
# 32532                  0.0               0.377551
# 32533                  0.0               0.397959
# 32534                  0.0               0.397959
# 32535                  0.0               0.193878
# 32536                  0.0               0.397959
#
# [32537 rows x 6 columns]

# %%
# 4️ Encoding
low_cat_cols = [col for col in cat_cols if df[col].nunique() <= 5]
high_cat_cols = [col for col in cat_cols if df[col].nunique() > 5]

# %%
df = pd.get_dummies(df, columns=low_cat_cols, drop_first=True)

# %%
df
# Out:
#        age          workclass  fnlwgt    education  education_num  \
# 0       39          State-gov   77516    Bachelors             13
# 1       50   Self-emp-not-inc   83311    Bachelors             13
# 2       38            Private  215646      HS-grad              9
# 3       53            Private  234721         11th              7
# 4       28            Private  338409    Bachelors             13
# ...    ...                ...     ...          ...            ...
# 32532   27            Private  257302   Assoc-acdm             12
# 32533   40            Private  154374      HS-grad              9
# 32534   58            Private  151910      HS-grad              9
# 32535   22            Private  201490      HS-grad              9
# 32536   52       Self-emp-inc  287927      HS-grad              9
#
#             marital_status          occupation    relationship  capital_gain  \
# 0            Never-married        Adm-clerical   Not-in-family          2174
# 1       Married-civ-spouse     Exec-managerial         Husband             0
# 2                 Divorced   Handlers-cleaners   Not-in-family             0
# 3       Married-civ-spouse   Handlers-cleaners         Husband             0
# 4       Married-civ-spouse      Prof-specialty            Wife             0
# ...                    ...                 ...             ...           ...
# 32532   Married-civ-spouse        Tech-support            Wife             0
# 32533   Married-civ-spouse   Machine-op-inspct         Husband             0
# 32534              Widowed        Adm-clerical       Unmarried             0
# 32535        Never-married        Adm-clerical       Own-child             0
# 32536   Married-civ-spouse     Exec-managerial            Wife         15024
#
#        capital_loss  hours_per_week  native_country  race_ Asian-Pac-Islander  \
# 0                 0              40   United-States                     False
# 1                 0              13   United-States                     False
# 2                 0              40   United-States                     False
# 3                 0              40   United-States                     False
# 4                 0              40            Cuba                     False
# ...             ...             ...             ...                       ...
# 32532             0              38   United-States                     False
# 32533             0              40   United-States                     False
# 32534             0              40   United-States                     False
# 32535             0              20   United-States                     False
# 32536             0              40   United-States                     False
#
#        race_ Black  race_ Other  race_ White  sex_ Male  income_ >50K
# 0            False        False         True       True         False
# 1            False        False         True       True         False
# 2            False        False         True       True         False
# 3             True        False        False       True         False
# 4             True        False        False      False         False
# ...            ...          ...          ...        ...           ...
# 32532        False        False         True      False         False
# 32533        False        False         True       True          True
# 32534        False        False         True      False         False
# 32535        False        False         True       True         False
# 32536        False        False         True      False          True
#
# [32537 rows x 18 columns]

# %%
le = LabelEncoder()
for col in high_cat_cols:
    df[col] = le.fit_transform(df[col])

# %%
df
# Out:
#        age  workclass  fnlwgt  education  education_num  marital_status  \
# 0       39          7   77516          9             13               4
# 1       50          6   83311          9             13               2
# 2       38          4  215646         11              9               0
# 3       53          4  234721          1              7               2
# 4       28          4  338409          9             13               2
# ...    ...        ...     ...        ...            ...             ...
# 32532   27          4  257302          7             12               2
# 32533   40          4  154374         11              9               2
# 32534   58          4  151910         11              9               6
# 32535   22          4  201490         11              9               4
# 32536   52          5  287927         11              9               2
#
#        occupation  relationship  capital_gain  capital_loss  hours_per_week  \
# 0               1             1          2174             0              40
# 1               4             0             0             0              13
# 2               6             1             0             0              40
# 3               6             0             0             0              40
# 4              10             5             0             0              40
# ...           ...           ...           ...           ...             ...
# 32532          13             5             0             0              38
# 32533           7             0             0             0              40
# 32534           1             4             0             0              40
# 32535           1             3             0             0              20
# 32536           4             5         15024             0              40
#
#        native_country  race_ Asian-Pac-Islander  race_ Black  race_ Other  \
# 0                  39                     False        False        False
# 1                  39                     False        False        False
# 2                  39                     False        False        False
# 3                  39                     False         True        False
# 4                   5                     False         True        False
# ...               ...                       ...          ...          ...
# 32532              39                     False        False        False
# 32533              39                     False        False        False
# 32534              39                     False        False        False
# 32535              39                     False        False        False
# 32536              39                     False        False        False
#
#        race_ White  sex_ Male  income_ >50K
# 0             True       True         False
# 1             True       True         False
# 2             True       True         False
# 3            False       True         False
# 4            False      False         False
# ...            ...        ...           ...
# 32532         True      False         False
# 32533         True       True          True
# 32534         True      False         False
# 32535         True       True         False
# 32536         True      False          True
#
# [32537 rows x 18 columns]

# %%
#  Feature Engineering

df['age_group'] = pd.cut(df['age'], bins=[0, 25, 45, 65, 100], labels=['Young', 'Mid-Age', 'Senior', 'Elder'])
df['work_experience_level'] = pd.cut(df['hours_per_week'], bins=[0, 25, 40, 60, 100], labels=['Low', 'Moderate', 'High', 'Extreme'])

# %%
# Log Transformation

df['capital_gain_log'] = np.log1p(df['capital_gain'])

plt.figure(figsize=(6,4))
sns.histplot(df['capital_gain_log'], kde=True)
plt.title("After Log Transformation - capital-gain")
plt.show()

# %%
df.head()
# Out:
#    age  workclass  fnlwgt  education  education_num  marital_status  \
# 0   39          7   77516          9             13               4
# 1   50          6   83311          9             13               2
# 2   38          4  215646         11              9               0
# 3   53          4  234721          1              7               2
# 4   28          4  338409          9             13               2
#
#    occupation  relationship  capital_gain  capital_loss  ...  native_country  \
# 0           1             1          2174             0  ...              39
# 1           4             0             0             0  ...              39
# 2           6             1             0             0  ...              39
# 3           6             0             0             0  ...              39
# 4          10             5             0             0  ...               5
#
#    race_ Asian-Pac-Islander  race_ Black  race_ Other  race_ White  sex_ Male  \
# 0                     False        False        False         True       True
# 1                     False        False        False         True       True
# 2                     False        False        False         True       True
# 3                     False         True        False        False       True
# 4                     False         True        False        False      False
#
#    income_ >50K  age_group work_experience_level capital_gain_log
# 0         False    Mid-Age              Moderate         7.684784
# 1         False     Senior                   Low         0.000000
# 2         False    Mid-Age              Moderate         0.000000
# 3         False     Senior              Moderate         0.000000
# 4         False    Mid-Age              Moderate         0.000000
#
# [5 rows x 21 columns]

# %%
## two new features
df['hours_per_age'] = df['hours_per_week'] / df['age']
df['capital_net'] = df['capital_gain'] - df['capital_loss']

# %%
# skewness
sns.histplot(df['capital_gain'], bins=50, kde=True)
plt.show()

# Apply log transformation to reduce skewness
df['capital_gain_log'] = np.log1p(df['capital_gain'])

# %%
# capital-gain is highly right-skewed. Log transformation reduces skewness, stabilizes variance, and improves model performance.

# %% [markdown]
# One-Hot Encoding (OHE)
# Pros:
# Doesn’t assume any order among categories.
# Good for linear models (like Logistic Regression).
# Easy to interpret.
# Cons:
# Increases number of columns (high dimensionality).
# Creates sparse data (lots of zeros).
# Can be inefficient for tree-based models.

# %% [markdown]
# Label Encoding (LE)
# Pros:
# Simple and compact (no extra columns).
# Memory-efficient.
# Works well with tree-based models (Decision Trees, Random Forest).
# Cons:
# Imposes a false order among categories.
# Not suitable for linear models.
# Harder to interpret.
